# %%
import pandas as pd

# %%
df = pd.read_csv('credit_score_cleaned_train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96696 entries, 0 to 96695
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        96696 non-null  object
#  1   customer_id               96696 non-null  object
#  2   month                     96696 non-null  object
#  3   name                      96696 non-null  object
#  4   age                       96696 non-null  int64
#  5   ssn                       96696 non-null  object
#  6   occupation                96696 non-null  object
#  7   annual_income             96696 non-null  float64
#  8   monthly_inhand_salary     96696 non-null  float64
#  9   credit_history_age        96696 non-null  int64
#  10  total_emi_per_month       96696 non-null  float64
#  11  num_bank_accounts         96696 non-null  int64
#  12  num_credit_card           96696 non-null  int64
#  13  interest_rate             96696 non-null  int64
#  14  num_of_loan               96696 non-null  int64
#  15  type_of_loan              96696 non-null  object
#  16  delay_from_due_date       96696 non-null  int64
#  17  num_of_delayed_payment    96696 non-null  int64
#  18  changed_credit_limit      96696 non-null  float64
#  19  num_credit_inquiries      96696 non-null  int64
#  20  credit_mix                96696 non-null  object
#  21  outstanding_debt          96696 non-null  float64
#  22  credit_utilization_ratio  96696 non-null  float64
#  23  payment_of_min_amount     96696 non-null  object
#  24  amount_invested_monthly   96696 non-null  float64
#  25  payment_behaviour         96696 non-null  object
#  26  monthly_balance           96696 non-null  float64
#  27  credit_score              96696 non-null  int64
# dtypes: float64(8), int64(10), object(10)
# memory usage: 20.7+ MB

# %%
df.shape
# Out:
# (96696, 28)

# %%
df['credit_history_age']
# Out:
# 0         89
# 1         93
# 2         91
# 3         92
# 4         93
#         ...
# 96691    130
# 96692    131
# 96693    132
# 96694    133
# 96695    134
# Name: credit_history_age, Length: 96696, dtype: int64

# %%
df['occupation'].unique()
# Out:
# array(['Scientist', 'Teacher', 'Engineer', 'Entrepreneur', 'Developer',
#        'Lawyer', 'Media_Manager', 'Doctor', 'Journalist', 'Manager',
#        'Accountant', 'Musician', 'Mechanic', 'Writer', 'Architect'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# id                          0
# customer_id                 0
# month                       0
# name                        0
# age                         0
# ssn                         0
# occupation                  0
# annual_income               0
# monthly_inhand_salary       0
# credit_history_age          0
# total_emi_per_month         0
# num_bank_accounts           0
# num_credit_card             0
# interest_rate               0
# num_of_loan                 0
# type_of_loan                0
# delay_from_due_date         0
# num_of_delayed_payment      0
# changed_credit_limit        0
# num_credit_inquiries        0
# credit_mix                  0
# outstanding_debt            0
# credit_utilization_ratio    0
# payment_of_min_amount       0
# amount_invested_monthly     0
# payment_behaviour           0
# monthly_balance             0
# credit_score                0
# dtype: int64

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.scatterplot(x=df['amount_invested_monthly'],y=df['credit_score'])
# Out:
# <Axes: xlabel='amount_invested_monthly', ylabel='credit_score'>

# %%
sns.boxplot(df, orient='h')
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df['payment_of_min_amount'],y=df['credit_score'])
# Out:
# <Axes: xlabel='payment_of_min_amount', ylabel='credit_score'>

# %%
x = df[[ 'age',
       'annual_income', 'monthly_inhand_salary', 'credit_history_age',
       'total_emi_per_month', 'num_bank_accounts', 'num_credit_card',
       'interest_rate', 'num_of_loan', 'delay_from_due_date',
       'num_of_delayed_payment', 'changed_credit_limit',
       'num_credit_inquiries', 'outstanding_debt',
       'credit_utilization_ratio',
       'amount_invested_monthly',  'monthly_balance']]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2,random_state=42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96696 entries, 0 to 96695
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        96696 non-null  object
#  1   customer_id               96696 non-null  object
#  2   month                     96696 non-null  object
#  3   name                      96696 non-null  object
#  4   age                       96696 non-null  int64
#  5   ssn                       96696 non-null  object
#  6   occupation                96696 non-null  object
#  7   annual_income             96696 non-null  float64
#  8   monthly_inhand_salary     96696 non-null  float64
#  9   credit_history_age        96696 non-null  int64
#  10  total_emi_per_month       96696 non-null  float64
#  11  num_bank_accounts         96696 non-null  int64
#  12  num_credit_card           96696 non-null  int64
#  13  interest_rate             96696 non-null  int64
#  14  num_of_loan               96696 non-null  int64
#  15  type_of_loan              96696 non-null  object
#  16  delay_from_due_date       96696 non-null  int64
#  17  num_of_delayed_payment    96696 non-null  int64
#  18  changed_credit_limit      96696 non-null  float64
#  19  num_credit_inquiries      96696 non-null  int64
#  20  credit_mix                96696 non-null  object
#  21  outstanding_debt          96696 non-null  float64
#  22  credit_utilization_ratio  96696 non-null  float64
#  23  payment_of_min_amount     96696 non-null  object
#  24  amount_invested_monthly   96696 non-null  float64
#  25  payment_behaviour         96696 non-null  object
#  26  monthly_balance           96696 non-null  float64
#  27  credit_score              96696 non-null  int64
# dtypes: float64(8), int64(10), object(10)
# memory usage: 20.7+ MB

# %%
df['month']
# Out:
# 0         January
# 1        February
# 2           March
# 3           April
# 4             May
#            ...
# 96691       April
# 96692         May
# 96693        June
# 96694        July
# 96695      August
# Name: month, Length: 96696, dtype: object

# %%
df['customer_id']
# Out:
# 0         CUS_0xd40
# 1         CUS_0xd40
# 2         CUS_0xd40
# 3         CUS_0xd40
# 4         CUS_0xd40
#             ...
# 96691    CUS_0x942c
# 96692    CUS_0x942c
# 96693    CUS_0x942c
# 96694    CUS_0x942c
# 96695    CUS_0x942c
# Name: customer_id, Length: 96696, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'customer_id', 'month', 'name', 'age', 'ssn', 'occupation',
#        'annual_income', 'monthly_inhand_salary', 'credit_history_age',
#        'total_emi_per_month', 'num_bank_accounts', 'num_credit_card',
#        'interest_rate', 'num_of_loan', 'type_of_loan', 'delay_from_due_date',
#        'num_of_delayed_payment', 'changed_credit_limit',
#        'num_credit_inquiries', 'credit_mix', 'outstanding_debt',
#        'credit_utilization_ratio', 'payment_of_min_amount',
#        'amount_invested_monthly', 'payment_behaviour', 'monthly_balance',
#        'credit_score'],
#       dtype='object')

# %%
x
# Out:
#        age  annual_income  monthly_inhand_salary  credit_history_age  \
# 0       23       19114.12              1824.8434                  89
# 1       23       19114.12              1824.8434                  93
# 2       23       19114.12              1824.8434                  91
# 3       23       19114.12              1824.8434                  92
# 4       23       19114.12              1824.8434                  93
# ...    ...            ...                    ...                 ...
# 96691   25       39628.99              3359.4158                 130
# 96692   25       39628.99              3359.4158                 131
# 96693   25       39628.99              3359.4158                 132
# 96694   25       39628.99              3359.4158                 133
# 96695   25       39628.99              3359.4158                 134
#
#        total_emi_per_month  num_bank_accounts  num_credit_card  interest_rate  \
# 0                49.574947                  3                4              3
# 1                49.574947                  3                4              3
# 2                49.574947                  3                4              3
# 3                49.574947                  3                4              3
# 4                49.574947                  3                4              3
# ...                    ...                ...              ...            ...
# 96691            35.104023                  4                6              7
# 96692            35.104023                  4                6              7
# 96693            35.104023                  4                6              7
# 96694            35.104023                  4                6              7
# 96695            35.104023                  4                6              7
#
#        num_of_loan  delay_from_due_date  num_of_delayed_payment  \
# 0                4                    3                       7
# 1                4                   -1                       7
# 2                4                    3                       7
# 3                4                    5                       4
# 4                4                    6                       4
# ...            ...                  ...                     ...
# 96691            2                   23                       7
# 96692            2                   18                       7
# 96693            2                   27                       6
# 96694            2                   20                       6
# 96695            2                   18                       6
#
#        changed_credit_limit  num_credit_inquiries  outstanding_debt  \
# 0                     11.27                     4            809.98
# 1                     11.27                     4            809.98
# 2                     11.27                     4            809.98
# 3                      6.27                     4            809.98
# 4                     11.27                     4            809.98
# ...                     ...                   ...               ...
# 96691                 11.50                     3            502.38
# 96692                 11.50                     3            502.38
# 96693                 11.50                     3            502.38
# 96694                 11.50                     3            502.38
# 96695                 11.50                     3            502.38
#
#        credit_utilization_ratio  amount_invested_monthly  monthly_balance
# 0                     26.822620                80.415300        312.49408
# 1                     31.944960               118.280220        284.62915
# 2                     28.609352                81.699524        331.20987
# 3                     31.377861               199.458070        223.45131
# 4                     24.797346                41.420155        341.48923
# ...                         ...                      ...              ...
# 96691                 34.663570                60.971333        479.86624
# 96692                 40.565630                54.185950        496.65160
# 96693                 41.255524                24.028477        516.80910
# 96694                 33.638206               251.672580        319.16498
# 96695                 34.192463               167.163860        393.67370
#
# [96696 rows x 17 columns]

# %%
y
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 96691    0
# 96692    0
# 96693    0
# 96694    1
# 96695    0
# Name: credit_score, Length: 96696, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
pred_knn = model_knn.predict(x_test)

# %%
y_test
# Out:
# 84331    1
# 34978    1
# 92656    0
# 29435    1
# 77230    0
#         ..
# 94163    0
# 32564    1
# 80217    0
# 86962    1
# 82301    1
# Name: credit_score, Length: 19340, dtype: int64

# %%
model_knn.score(x_train,y_train)
# Out:
# 0.8286752158849993

# %%
model_knn.score(x_test,y_test)
# Out:
# 0.7349017580144778

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75      5505
#            1       0.76      0.77      0.76     10321
#            2       0.67      0.58      0.62      3514
#
#     accuracy                           0.73     19340
#    macro avg       0.72      0.71      0.71     19340
# weighted avg       0.73      0.73      0.73     19340

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,pred_knn)
# Out:
# array([[4244, 1192,   69],
#        [1452, 7945,  924],
#        [ 150, 1340, 2024]])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model_tree = DecisionTreeClassifier()

# %%
model_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_tree = model_tree.predict(x_test)

# %%
pred_tree
# Out:
# array([1, 2, 0, ..., 0, 1, 1])

# %%
y_test
# Out:
# 84331    1
# 34978    1
# 92656    0
# 29435    1
# 77230    0
#         ..
# 94163    0
# 32564    1
# 80217    0
# 86962    1
# 82301    1
# Name: credit_score, Length: 19340, dtype: int64

# %%
model_tree.score(x_train,y_train)
# Out:
# 1.0

# %%
model_tree.score(x_test,y_test)
# Out:
# 0.7274560496380559

# %%
print(classification_report(y_test,pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.72      5505
#            1       0.75      0.75      0.75     10321
#            2       0.66      0.66      0.66      3514
#
#     accuracy                           0.73     19340
#    macro avg       0.71      0.71      0.71     19340
# weighted avg       0.73      0.73      0.73     19340

# %%
confusion_matrix(y_test,pred_tree)
# Out:
# array([[3968, 1463,   74],
#        [1415, 7769, 1137],
#        [  82, 1100, 2332]])

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model_nb = GaussianNB()

# %%
model_nb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
model_nb.score(x_test,y_test)
# Out:
# 0.6031023784901758

# %%
model_nb.score(x_train,y_train)
# Out:
# 0.60176327628109

# %%
pred_nb = model_nb.predict(x_test)

# %%
print(confusion_matrix(y_test,pred_nb))
# Out:
# [[3871  715  919]
#  [2219 4932 3170]
#  [  75  578 2861]]

# %%
print(classification_report(y_test,pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.63      0.70      0.66      5505
#            1       0.79      0.48      0.60     10321
#            2       0.41      0.81      0.55      3514
#
#     accuracy                           0.60     19340
#    macro avg       0.61      0.67      0.60     19340
# weighted avg       0.68      0.60      0.61     19340

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_random = RandomForestClassifier(n_estimators=500)

# %%
model_random.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
model_random.score(x_train,y_train)
# Out:
# 1.0

# %%
model_random.score(x_test,y_test)
# Out:
# 0.8067218200620476

# %%
pred_random = model_random.predict(x_test)

# %%
print(classification_report(y_test,pred_random))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.83      0.81      5505
#            1       0.82      0.82      0.82     10321
#            2       0.78      0.74      0.76      3514
#
#     accuracy                           0.81     19340
#    macro avg       0.80      0.80      0.80     19340
# weighted avg       0.81      0.81      0.81     19340

# %%
confusion_matrix(y_test,pred_random)
# Out:
# array([[4583,  903,   19],
#        [1166, 8424,  731],
#        [  22,  897, 2595]])
